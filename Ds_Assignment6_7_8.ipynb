# %% [markdown]
# #  AQI(Air quality index) of different countries

# %% [markdown]
# Objective is to identify the Air quality of India compared to other countries in the world.
# Taken AQI of different countries data sheet and extract the data of India's AQI values.
# AQI:Air Quality Index (AQI) is used for reporting daily air quality.
# AQI values at or below 100 are generally thought of as satisfactory. When AQI values are above 100, air quality is unhealthy.
# The AQI is calculated by converting measured pollutant concentrations to a uniform index which is based on the health effects associated with a pollutant.
# Eight pollutants namely particulate matter (PM) 10, PM2. 5, Ozone (O3), Sulphur dioxide (SO2), nitrogen dioxide (NO2), carbon monoxide (CO), lead (Pb) and ammonia (NH3) act as major parameters in deriving the AQI of an area.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\DELL\Downloads\AQI and Lat Long of Countries.xlsx')
display(df)
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                        Brazil  Presidente Dutra         41         Good
# 3                         Italy   Priolo Gargallo         66     Moderate
# 4                        Poland         Przasnysz         34         Good
# ...                         ...               ...        ...          ...
# 16690  United States of America  Highland Springs         54     Moderate
# 16691                  Slovakia            Martin         71     Moderate
# 16692                  Slovakia            Martin         71     Moderate
# 16693                    France            Sceaux         50         Good
# 16694  United States of America       Westerville         71     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
print("\nMissing Values:")#finding missing values
print(df.isnull().sum())
# Out:
# Missing Values:
# Country               302
# City                    0
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# lat                     0
# lng                     0
# dtype: int64

# %%
df_result = df.dropna()
display(df_result)
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                        Brazil  Presidente Dutra         41         Good
# 3                         Italy   Priolo Gargallo         66     Moderate
# 4                        Poland         Przasnysz         34         Good
# ...                         ...               ...        ...          ...
# 16690  United States of America  Highland Springs         54     Moderate
# 16691                  Slovakia            Martin         71     Moderate
# 16692                  Slovakia            Martin         71     Moderate
# 16693                    France            Sceaux         50         Good
# 16694  United States of America       Westerville         71     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %% [markdown]
# Missing values are detected and droped the rows with missing value .Rows are droped because major missing values are country names that was not replaced by mean or any prediction so droped the rows.

# %%
print("\nDescriptive statistics:")
display(df_result.describe())
# Out:
# Descriptive statistics:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  16393.000000  16393.000000     16393.000000   16393.000000
# mean      63.227902      1.349356        31.794424       3.851156
# std       43.297779      2.390045        22.975905       5.911545
# min        7.000000      0.000000         0.000000       0.000000
# 25%       39.000000      1.000000        20.000000       0.000000
# 50%       52.000000      1.000000        29.000000       2.000000
# 75%       69.000000      1.000000        38.000000       5.000000
# max      500.000000    133.000000       222.000000      91.000000
#
#        PM2.5 AQI Value           lat           lng
# count     16393.000000  16393.000000  16393.000000
# mean         60.075520     30.330645     -4.223929
# std          43.378779     22.922043     72.909196
# min           0.000000    -54.801900   -159.771000
# 25%          34.000000     16.730000    -75.283300
# ...

# %% [markdown]
# From the descriptive  statistics average AQI value is less than 100 for all the countries so air quality is satisfactory.Stratospheric ozone is “good” because it protects living things from ultraviolet radiation from the sun.Ozone AQI value is between 0-50 it is good air quality.

# %%
sorted_df = df_result.sort_values('Country')#sorting
print("\nSorted DataFrame:")
display(sorted_df)
# Out:
# Sorted DataFrame:
#            Country        City  AQI Value                    AQI Category  \
# 14429  Afghanistan      Zaranj        133  Unhealthy for Sensitive Groups
# 15052  Afghanistan    Taywarah         62                        Moderate
# 12718  Afghanistan       Kabul         64                        Moderate
# 2374       Albania      Tirana         73                        Moderate
# 13592      Albania    Peshkopi        115  Unhealthy for Sensitive Groups
# ...            ...         ...        ...                             ...
# 13279     Zimbabwe      Mutare         29                            Good
# 16417     Zimbabwe  Beitbridge         52                        Moderate
# 16340     Zimbabwe    Bulawayo         65                        Moderate
# 2585      Zimbabwe      Kariba         62                        Moderate
# 461       Zimbabwe      Hwange         44                            Good
#
# ...

# %%
print("Data information:")
print(sorted_df.info())
# Out:
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16393 entries, 14429 to 461
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16393 non-null  object
#  1   City                16393 non-null  object
#  2   AQI Value           16393 non-null  int64
#  3   AQI Category        16393 non-null  object
#  4   CO AQI Value        16393 non-null  int64
#  5   CO AQI Category     16393 non-null  object
#  6   Ozone AQI Value     16393 non-null  int64
#  7   Ozone AQI Category  16393 non-null  object
#  8   NO2 AQI Value       16393 non-null  int64
#  9   NO2 AQI Category    16393 non-null  object
#  10  PM2.5 AQI Value     16393 non-null  int64
#  11  PM2.5 AQI Category  16393 non-null  object
#  12  lat                 16393 non-null  float64
#  13  lng                 16393 non-null  float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.9+ MB
# ...

# %%
mean_value = sorted_df['AQI Value'].mean()
print("\nMean value:", mean_value)

median_value = sorted_df['AQI Value'].median()
print("\nMedian value:", median_value)

mode_value = sorted_df['AQI Value'].mode()
print("\nMode value:")
print(mode_value)

std_value = df_result['AQI Value'].std()
print("\nStandard deviation:", std_value)

variance_value = df_result['AQI Value'].var()
print("\nVariance:", variance_value)

min_value = df_result['AQI Value'].min()
print("\nMinimum value:", min_value)

max_value = df_result['AQI Value'].max()
print("\nMaximum value:", max_value)

correlation = df_result['AQI Value'].corr(df['Ozone AQI Value'])
print("\nCorrelation:", correlation)

covariance = df_result['AQI Value'].cov(df['Ozone AQI Value'])
print("\nCovariance:", covariance)

unique_values = df_result['AQI Value'].nunique()
print("\nUnique values:", unique_values)
# Out:
# Mean value: 63.22790215335814
#
# Median value: 52.0
#
# Mode value:
# 0    50
# Name: AQI Value, dtype: int64
#
# Standard deviation: 43.29777928956275
#
# Variance: 1874.6976914076888
#
# Minimum value: 7
#
# Maximum value: 500
#
# Correlation: 0.3289592742123515
#
# Covariance: 327.2505508941446
#
# Unique values: 282

# %%
unique_values = sorted_df['Country'].nunique()
print("\nUnique values:", unique_values)
# Out:
# Unique values: 174

# %%
df1=sorted_df.loc[sorted_df['Country'] == 'India']
display(df1)
# Out:
#       Country          City  AQI Value AQI Category  CO AQI Value  \
# 4580    India       Saidpur        174    Unhealthy             4
# 9900    India        Vaikam         58     Moderate             0
# 15774   India     Daudnagar        150    Unhealthy             3
# 12368   India      Kakching         36         Good             1
# 8680    India  Sikandra Rao        178    Unhealthy             5
# ...       ...           ...        ...          ...           ...
# 8764    India       Shegaon        152    Unhealthy             1
# 16388   India      Kottayam         79     Moderate             1
# 7577    India      Lakhipur         55     Moderate             2
# 5220    India        Pujali        175    Unhealthy             3
# 14900   India       Chikodi         72     Moderate             1
#
#       CO AQI Category  Ozone AQI Value              Ozone AQI Category  \
# 4580             Good              173                       Unhealthy
# ...

# %%
df13=df1.loc[df1['AQI Value'] >= 150]
display(df13)
# Out:
#       Country          City  AQI Value    AQI Category  CO AQI Value  \
# 4580    India       Saidpur        174       Unhealthy             4
# 15774   India     Daudnagar        150       Unhealthy             3
# 8680    India  Sikandra Rao        178       Unhealthy             5
# 4581    India       Saidpur        174       Unhealthy             4
# 10530   India     Penugonda        153       Unhealthy             4
# ...       ...           ...        ...             ...           ...
# 6883    India    Manoharpur        177       Unhealthy             1
# 7639    India       Safidon        150       Unhealthy             2
# 7557    India       Khagaul        201  Very Unhealthy             2
# 8764    India       Shegaon        152       Unhealthy             1
# 5220    India        Pujali        175       Unhealthy             3
#
#       CO AQI Category  Ozone AQI Value              Ozone AQI Category  \
# ...

# %%
print("Data information:")
print(df1.info())
# Out:
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 794 entries, 4580 to 14900
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             794 non-null    object
#  1   City                794 non-null    object
#  2   AQI Value           794 non-null    int64
#  3   AQI Category        794 non-null    object
#  4   CO AQI Value        794 non-null    int64
#  5   CO AQI Category     794 non-null    object
#  6   Ozone AQI Value     794 non-null    int64
#  7   Ozone AQI Category  794 non-null    object
#  8   NO2 AQI Value       794 non-null    int64
#  9   NO2 AQI Category    794 non-null    object
#  10  PM2.5 AQI Value     794 non-null    int64
#  11  PM2.5 AQI Category  794 non-null    object
#  12  lat                 794 non-null    float64
#  13  lng                 794 non-null    float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 93.0+ KB
# ...

# %%
mode_value1 = df1['AQI Value'].mode()
print("\nMode value:")
print(mode_value1)

variance_value1 = df1['AQI Value'].var()
print("\nVariance:", variance_value1)

correlation1 = df1['AQI Value'].corr(df1['Ozone AQI Value'])
print("\nCorrelation:", correlation)

covariance1 = df1['AQI Value'].cov(df1['Ozone AQI Value'])
print("\nCovariance:", covariance)

unique_values1 = df1['AQI Value'].nunique()
print("\nUnique values:", unique_values)
# Out:
# Mode value:
# 0    500
# Name: AQI Value, dtype: int64
#
# Variance: 7359.678345790132
#
# Correlation: 0.3289592742123515
#
# Covariance: 327.2505508941446
#
# Unique values: 174

# %%
print("\nDescriptive statistics:")
display(df1.describe())
# Out:
# Descriptive statistics:
#         AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  794.000000    794.000000       794.000000     794.000000
# mean   142.734257      1.698992        53.974811       1.769521
# std     85.788568      1.467195        41.594625       3.483491
# min     24.000000      0.000000         1.000000       0.000000
# 25%     77.000000      1.000000        27.000000       0.000000
# 50%    151.000000      1.000000        37.000000       1.000000
# 75%    172.000000      2.000000        62.000000       2.000000
# max    500.000000     12.000000       199.000000      43.000000
#
#        PM2.5 AQI Value         lat         lng
# count       794.000000  794.000000  794.000000
# mean        140.110831   21.449855   79.346497
# std          80.076038    6.989192   12.661203
# min          16.000000   -8.733300 -120.775900
# 25%          76.250000   16.017825   76.186525
# 50%         150.000000   22.725000   78.741600
# ...

# %%
value_counts = df1['AQI Value'].value_counts()
print("\nValue counts:")
print(value_counts)
# Out:
# Value counts:
# 500    20
# 154    17
# 153    17
# 160    15
# 150    14
#        ..
# 26      1
# 249     1
# 110     1
# 28      1
# 147     1
# Name: AQI Value, Length: 211, dtype: int64

# %%
df2 = df_result.loc[df_result['Country'] <= 'India']
display (df2)
# Out:
#         Country              City  AQI Value                    AQI Category  \
# 1        Brazil  Presidente Dutra         41                            Good
# 2        Brazil  Presidente Dutra         41                            Good
# 7       Belgium             Puurs         64                        Moderate
# 9         China           Qinzhou         68                        Moderate
# 11       France           Raismes         59                        Moderate
# ...         ...               ...        ...                             ...
# 16684  Colombia           Viterbo         55                        Moderate
# 16685  Colombia           Viterbo         55                        Moderate
# 16686     China          Wangqing        101  Unhealthy for Sensitive Groups
# 16689     China          Shaoguan        160                       Unhealthy
# 16693    France            Sceaux         50                            Good
#
# ...

# %%
unique_values1 = df2['Country'].nunique()
print("\nUnique values:", unique_values1)
# Out:
# Unique values: 70

# %%
print("Data information:")
print(df2.info())
# Out:
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5827 entries, 1 to 16693
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             5827 non-null   object
#  1   City                5827 non-null   object
#  2   AQI Value           5827 non-null   int64
#  3   AQI Category        5827 non-null   object
#  4   CO AQI Value        5827 non-null   int64
#  5   CO AQI Category     5827 non-null   object
#  6   Ozone AQI Value     5827 non-null   int64
#  7   Ozone AQI Category  5827 non-null   object
#  8   NO2 AQI Value       5827 non-null   int64
#  9   NO2 AQI Category    5827 non-null   object
#  10  PM2.5 AQI Value     5827 non-null   int64
#  11  PM2.5 AQI Category  5827 non-null   object
#  12  lat                 5827 non-null   float64
#  13  lng                 5827 non-null   float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 682.9+ KB
# ...

# %%
print("\nDescriptive statistics:")
display(df2.describe())
# Out:
# Descriptive statistics:
#          AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  5827.000000   5827.000000      5827.000000    5827.000000
# mean     70.486871      1.410846        33.005663       2.677192
# std      55.654477      1.793609        30.932095       4.449314
# min       7.000000      0.000000         0.000000       0.000000
# 25%      36.500000      1.000000        16.500000       0.000000
# 50%      54.000000      1.000000        28.000000       1.000000
# 75%      77.500000      1.000000        37.000000       3.000000
# max     500.000000     35.000000       210.000000      69.000000
#
#        PM2.5 AQI Value          lat          lng
# count      5827.000000  5827.000000  5827.000000
# mean         67.703964    23.638410     9.165381
# std          53.840192    27.023164    62.075601
# min           0.000000   -54.801900  -149.566700
# 25%          34.000000     5.816650   -42.847900
# 50%          53.000000    26.243500     7.900800
# ...

# %%
mode_value2 = df2['AQI Value'].mode()
print("\nMode value:")
print(mode_value2)

variance_value2= df2['AQI Value'].var()
print("\nVariance:", variance_value2)

correlation2 = df2['AQI Value'].corr(df2['Ozone AQI Value'])
print("\nCorrelation:", correlation2)

covariance2 = df2['AQI Value'].cov(df2['Ozone AQI Value'])
print("\nCovariance:", covariance2)

unique_values2 = df2['AQI Value'].nunique()
print("\nUnique values:", unique_values2)
# Out:
# Mode value:
# 0    38
# Name: AQI Value, dtype: int64
#
# Variance: 3097.4208282984173
#
# Correlation: 0.4563995379623488
#
# Covariance: 785.6961780366986
#
# Unique values: 253

# %%
df11 = df1.drop(['AQI Category','CO AQI Category','Ozone AQI Category','NO2 AQI Category','PM2.5 AQI Category','lat','lng','Country','City'], axis=1)
print("\nDataFrame with column removed:")
display(df11)
# Out:
# DataFrame with column removed:
#        AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# 4580         174             4              173              2
# 9900          58             0               26              0
# 15774        150             3              139              1
# 12368         36             1               17              0
# 8680         178             5               37             20
# ...          ...           ...              ...            ...
# 8764         152             1               32              0
# 16388         79             1               23              1
# 7577          55             2               29              0
# 5220         175             3              104              3
# 14900         72             1               30              1
#
#        PM2.5 AQI Value
# 4580               174
# 9900                58
# 15774              150
# 12368               36
# 8680               178
# ...                ...
# ...

# %%
df21 = df2.drop(['AQI Category','CO AQI Category','Ozone AQI Category','NO2 AQI Category','PM2.5 AQI Category','lat','lng','Country','City'], axis=1)
print("\nDataFrame with column removed:")
display(df21)
# Out:
# DataFrame with column removed:
#        AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# 1             41             1                5              1
# 2             41             1                5              1
# 7             64             1               29              7
# 9             68             2               68              1
# 11            59             1               30              4
# ...          ...           ...              ...            ...
# 16684         55             1               24              0
# 16685         55             1               24              0
# 16686        101             3               35              2
# 16689        160             3              160              1
# 16693         50             1               20              5
#
#        PM2.5 AQI Value
# 1                   41
# 2                   41
# 7                   64
# 9                   58
# 11                  59
# ...                ...
# ...

# %%
median_value = sorted_df['AQI Value'].median()
print("\nMedian value:", median_value)

median_value1=df11['AQI Value'].median()
print("\nMedian value ofIndia:", median_value1)

median_value2=df21['AQI Value'].median()
print("\nMedian value of other countries:", median_value2)
# Out:
# Median value: 52.0
#
# Median value ofIndia: 151.0
#
# Median value of other countries: 54.0

# %%
plt.hist([df11['AQI Value'],df11['Ozone AQI Value'],df11['NO2 AQI Value'],df11['PM2.5 AQI Value']], bins=10)
plt.title("Histogram of India")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
plt.hist([df2['AQI Value'],df2['Ozone AQI Value'],df2['NO2 AQI Value'],df2['PM2.5 AQI Value']], bins=10)
plt.title("Histogram of other countries")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
plt.boxplot([df11['AQI Value'],df11['Ozone AQI Value'],df11['NO2 AQI Value'],df11['PM2.5 AQI Value']])
plt.title("Box Plot of India")
plt.ylabel("Values")
plt.xticks(range(len(df11.columns)), df11.columns, rotation=90)
plt.show()

plt.boxplot([df21['AQI Value'],df21['Ozone AQI Value'],df21['NO2 AQI Value'],df21['PM2.5 AQI Value']])
plt.title("Box Plot of other countries")
plt.ylabel("Values")
plt.xticks(range(len(df21.columns)), df21.columns, rotation=90)
plt.show()

# %% [markdown]
# Outliers in the box plot shows the more cities  having Maximum AQI values, ozone AQI values etc.
# This is to think about how to reduce air pollution.Here ozone AQI value is more in some countries if it is continously increasing this may lead to drought on the earth.Here ozone AQI value is greater than 150 it is unhealthy.

# %%
df11['AQI Value'].plot.kde()
plt.title("Kernel Density Plot for India")
plt.xlabel("Values")
plt.ylabel("Density")
plt.show()

df21['AQI Value'].plot.kde()
plt.title("Kernel Density Plot for other countries")
plt.xlabel("Values")
plt.ylabel("Density")
plt.show()

# %%
plt.scatter(df11["AQI Value"],df11["CO AQI Value"],c="green",s=100)
plt.scatter(df11["AQI Value"],df11["Ozone AQI Value"],c="blue",s=10)
plt.scatter(df11["AQI Value"],df11["NO2 AQI Value"],c="black",s=20)
plt.scatter(df11["AQI Value"],df11["PM2.5 AQI Value"],c="pink",s=30)
plt.title("Scatter plot of India")
# Out:
# Text(0.5, 1.0, 'Scatter plot of India')

# %%
plt.scatter(df21["AQI Value"],df21["CO AQI Value"],c="green",s=100)
plt.scatter(df21["AQI Value"],df21["Ozone AQI Value"],c="blue",s=10)
plt.scatter(df21["AQI Value"],df21["NO2 AQI Value"],c="black",s=20)
plt.scatter(df21["AQI Value"],df21["PM2.5 AQI Value"],c="pink",s=30)
plt.title("Scatter Plot of other countries")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of other countries')

# %%
correlation_matrix = df11.corr()

# %%
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.title("Correlation Matrix of India")
plt.colorbar()
plt.xticks(range(len(df11.columns)), df11.columns, rotation=90)
plt.yticks(range(len(df11.columns)), df11.columns)
plt.show()

# %%
correlation_matrix1 = df21.corr()

# %%
plt.imshow(correlation_matrix1, cmap='coolwarm', interpolation='nearest')
plt.title("Correlation Matrix of other countries")
plt.colorbar()
plt.xticks(range(len(df21.columns)), df21.columns, rotation=90)
plt.yticks(range(len(df21.columns)), df21.columns)
plt.show()

# %%
df11.plot()
plt.title('line plot for India AQI values')

df21.plot()
plt.title('line plot for other countries AQI values')
# Out:
# Text(0.5, 1.0, 'line plot for other countries AQI values')

# %%
df11= np.random.rand(10, 10)
plt.imshow(df11, cmap='hot', interpolation='nearest')
plt.title("Heatmap for India")
plt.colorbar()
plt.show()

# %%
df21 = np.random.rand(10, 10)
plt.imshow(df21, cmap='hot', interpolation='nearest')
plt.title("Heatmap for other countries")
plt.colorbar()
plt.show()

# %%
labels = ['AQI Value','CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']
means = [142.734257,1.69899,53.974811,1.769521,140.110831]
plt.pie(means, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title("Pie Chart of India AQI values")
plt.show()

labels = ['AQI Value','CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']
means = [70.486871,1.410846,33.005663,2.677192,67.703964]
plt.pie(means, labels=labels, autopct='%1.1f%%', shadow=True)
plt.title("Pie Chart of India AQI values")
plt.show()

# %% [markdown]
# From the above pie charts overall countries AQI values are moderately safe and India AQI values are greater than the WHO guide lines there are 413 cities.

# %%
print("Skewness of India AQI values")
skewvalue=df11.skew()
display(skewvalue)
# Out:
# Skewness of India AQI values
# AQI Value          1.955484
# CO AQI Value       1.788498
# Ozone AQI Value    1.641102
# NO2 AQI Value      4.959308
# PM2.5 AQI Value    1.703845
# dtype: float64

# %%
print("Kurtosis of India AQI values")
kurt1=df11.kurt()
display(kurt1)
# Out:
# Kurtosis of India AQI values
# AQI Value           5.957168
# CO AQI Value        6.427635
# Ozone AQI Value     1.723288
# NO2 AQI Value      37.601643
# PM2.5 AQI Value     5.096553
# dtype: float64

# %%
print("Skewness of All countries AQI values")
skewvalue1=df21.skew()
display(skewvalue1)
# Out:
# Skewness of All countries AQI values
# AQI Value          2.932796
# CO AQI Value       6.601599
# Ozone AQI Value    2.946659
# NO2 AQI Value      4.728680
# PM2.5 AQI Value    2.670868
# dtype: float64

# %%
print("Kurtosis of All countries AQI values")
kurt2=df21.kurt()
display(kurt2)
# Out:
# Kurtosis of All countries AQI values
# AQI Value          14.309946
# CO AQI Value       73.756721
# Ozone AQI Value    10.261222
# NO2 AQI Value      37.967927
# PM2.5 AQI Value    12.080725
# dtype: float64

# %% [markdown]
# The above data is highly skewed because skewness values are greater than 1. Except ozone AQI value all the data is leptokurtic (kurtosis>3) distribution of data is tall and thin.

# %% [markdown]
# DESCRIPTION:
# Skewness is a measure of asymmetry of a distribution.
# In a normal distribution, the mean divides the curve symmetrically into two equal parts at the median and the value of skewness is zero.
# When a distribution is asymmetrical the tail of the distribution is skewed to one side-to the right or to the left.
# When the value of the skewness is negative, the tail of the distribution is longer towards the left hand side of the curve.
# When the value of the skewness is positive, the tail of the distribution is longer towards the right hand side of the curve.
#
# Kurtosis is one of the two measures that quantify shape of a distribution. kutosis determine the volume of the outlier.Kurtosis describes the peakedness of the distribution.
# If the distribution is tall and thin it is called a leptokurtic distribution(Kurtosis > 3). Values in a leptokurtic distribution are near the mean or at the extremes.
# A flat distribution where the values are moderately spread out (i.e., unlike leptokurtic) is called platykurtic(Kurtosis <3) distribution.
# A distribution whose shape is in between a leptokurtic distribution and a platykurtic distribution is called a mesokurtic(Kurtosis=3) distribution. A mesokurtic distribution looks more close to a normal distribution.
# Kurtosis is sometimes reported as “excess kurtosis.” Excess kurtosis is determined by subtracting 3 from the kurtosis. This makes the normal distribution kurtosis equal 0.
#
# CONCLUSION:
# Least polluted cities in india:
# Imphal ,Madikeri ,Mysuru ,Mangalore,Amaravati ,Haldia ,Gorakhpur ,Bagalkot .
# Highest polluted cities in India:
# Delhi,Faridabad,Ghaziabad,Patna,Muzaffarpur,Noida,Meerut,Gobindgarh.
# To reduce air pollution:
# Don’t burn leaves, trash, and other smoky materials.
# Delay the number of trips you take in your car or motorcycle.
# Cutting down trees and forests is causing an increase in air pollution.Plant more trees and use less power.
# Use of fans instead of Air Conditioner.
